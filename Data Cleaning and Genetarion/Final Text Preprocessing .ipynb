# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re 
from wordcloud import WordCloud 
import gensim
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Conv1D, MaxPooling1D 
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %%
real_news_data = pd.read_csv("True.csv")
real_news_data
fake_df=pd.read_csv("Fake.csv")
fake_df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
real_news_data["label"] = 0
fake_df["label"] = 1

# %%
concatenated_df = pd.concat([real_news_data, fake_df])
columns_to_drop = ['subject', 'date']
concatenated_df = concatenated_df.drop(columns=columns_to_drop)

# %%
concatenated_df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text  label
# 0      WASHINGTON (Reuters) - The head of a conservat...      0
# 1      WASHINGTON (Reuters) - Transgender people will...      0
# 2      WASHINGTON (Reuters) - The special counsel inv...      0
# ...

# %%
df_2=pd.read_csv("news.csv")
df_2
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# ...          ...                                                ...
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# ...

# %%
for index, value in enumerate(df_2['label']):
    if value == 'FAKE':
        df_2.at[index, 'label'] = 1
    elif value == 'REAL':
        df_2.at[index, 'label'] = 0

# %%
df_2
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# ...          ...                                                ...
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...     1
# ...

# %%
concatenated_df = pd.concat([concatenated_df, df_2])
concatenated_df
# Out:
#                                                   title  \
# 0     As U.S. budget fight looms, Republicans flip t...
# 1     U.S. military to accept transgender recruits o...
# 2     Senior U.S. Republican senator: 'Let Mr. Muell...
# 3     FBI Russia probe helped by Australian diplomat...
# 4     Trump wants Postal Service to charge 'much mor...
# ...                                                 ...
# 6330  State Department says it can't find emails fro...
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333  In Ethiopia, Obama seeks progress on peace, se...
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label  Unnamed: 0
# 0     WASHINGTON (Reuters) - The head of a conservat...     0         NaN
# 1     WASHINGTON (Reuters) - Transgender people will...     0         NaN
# ...

# %%
third_dataset=pd.read_csv("WELFake_Dataset.csv")

# %%
third_dataset
# Out:
#        Unnamed: 0                                              title  \
# 0               0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1               1                                                NaN
# 2               2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3               3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4               4  SATAN 2: Russia unvelis an image of its terrif...
# ...           ...                                                ...
# 72129       72129  Russians steal research on Trump in hack of U....
# 72130       72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131       72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132       72132  Trump tussle gives unpopular Mexican leader mu...
# 72133       72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# ...

# %%
third_dataset.drop_duplicates(inplace=True)

# %%
third_dataset
# Out:
#        Unnamed: 0                                              title  \
# 0               0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1               1                                                NaN
# 2               2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3               3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4               4  SATAN 2: Russia unvelis an image of its terrif...
# ...           ...                                                ...
# 72129       72129  Russians steal research on Trump in hack of U....
# 72130       72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131       72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132       72132  Trump tussle gives unpopular Mexican leader mu...
# 72133       72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# ...

# %%
df=pd.concat([concatenated_df,third_dataset])

# %%
df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 72129  Russians steal research on Trump in hack of U....
# 72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132  Trump tussle gives unpopular Mexican leader mu...
# 72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text label  Unnamed: 0
# 0      WASHINGTON (Reuters) - The head of a conservat...     0         NaN
# 1      WASHINGTON (Reuters) - Transgender people will...     0         NaN
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 72129  Russians steal research on Trump in hack of U....
# 72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132  Trump tussle gives unpopular Mexican leader mu...
# 72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text label  Unnamed: 0
# 0      WASHINGTON (Reuters) - The head of a conservat...     0         NaN
# 1      WASHINGTON (Reuters) - Transgender people will...     0         NaN
# ...

# %%
df.drop(df.columns[-1], axis=1, inplace=True)

# %%
df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 72129  Russians steal research on Trump in hack of U....
# 72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132  Trump tussle gives unpopular Mexican leader mu...
# 72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text label
# 0      WASHINGTON (Reuters) - The head of a conservat...     0
# 1      WASHINGTON (Reuters) - Transgender people will...     0
# 2      WASHINGTON (Reuters) - The special counsel inv...     0
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 72108  Kris Kobach: Democrats Already Attacking Elect...
# 72109  Police Are Now Warning People To Take A Photo ...
# 72117  Tested by Russia, NATO Struggles to Stay Credi...
# 72123  Dallas, Roger Federer, Hillary Clinton: Your F...
# 72124  An Unlikely Contender Rises in France as the A...
#
#                                                     text label
# 0      WASHINGTON (Reuters) - The head of a conservat...     0
# 1      WASHINGTON (Reuters) - Transgender people will...     0
# 2      WASHINGTON (Reuters) - The special counsel inv...     0
# ...

# %%
df["combined_text"]=df

# %%
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 72108  Kris Kobach: Democrats Already Attacking Elect...
# 72109  Police Are Now Warning People To Take A Photo ...
# 72117  Tested by Russia, NATO Struggles to Stay Credi...
# 72123  Dallas, Roger Federer, Hillary Clinton: Your F...
# 72124  An Unlikely Contender Rises in France as the A...
#
#                                                     text label  \
# 0      WASHINGTON (Reuters) - The head of a conservat...     0
# 1      WASHINGTON (Reuters) - Transgender people will...     0
# 2      WASHINGTON (Reuters) - The special counsel inv...     0
# ...

# %%
columns_to_drop = ['title', 'text']
df = df.drop(columns=columns_to_drop)

# %%
df
# Out:
#       label                                      combined_text
# 0         0  As U.S. budget fight looms, Republicans flip t...
# 1         0  U.S. military to accept transgender recruits o...
# 2         0  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3         0  FBI Russia probe helped by Australian diplomat...
# 4         0  Trump wants Postal Service to charge 'much mor...
# ...     ...                                                ...
# 72108     0  Kris Kobach: Democrats Already Attacking Elect...
# 72109     1  Police Are Now Warning People To Take A Photo ...
# 72117     0  Tested by Russia, NATO Struggles to Stay Credi...
# 72123     0  Dallas, Roger Federer, Hillary Clinton: Your F...
# 72124     0  An Unlikely Contender Rises in France as the A...
#
# [63678 rows x 2 columns]

# %%
df = df[['combined_text', 'label']]
df
# Out:
#                                            combined_text label
# 0      As U.S. budget fight looms, Republicans flip t...     0
# 1      U.S. military to accept transgender recruits o...     0
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...     0
# 3      FBI Russia probe helped by Australian diplomat...     0
# 4      Trump wants Postal Service to charge 'much mor...     0
# ...                                                  ...   ...
# 72108  Kris Kobach: Democrats Already Attacking Elect...     0
# 72109  Police Are Now Warning People To Take A Photo ...     1
# 72117  Tested by Russia, NATO Struggles to Stay Credi...     0
# 72123  Dallas, Roger Federer, Hillary Clinton: Your F...     0
# 72124  An Unlikely Contender Rises in France as the A...     0
#
# [63678 rows x 2 columns]

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                                            combined_text label
# 0      As U.S. budget fight looms, Republicans flip t...     0
# 1      U.S. military to accept transgender recruits o...     0
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...     0
# 3      FBI Russia probe helped by Australian diplomat...     0
# 4      Trump wants Postal Service to charge 'much mor...     0
# ...                                                  ...   ...
# 72108  Kris Kobach: Democrats Already Attacking Elect...     0
# 72109  Police Are Now Warning People To Take A Photo ...     1
# 72117  Tested by Russia, NATO Struggles to Stay Credi...     0
# 72123  Dallas, Roger Federer, Hillary Clinton: Your F...     0
# 72124  An Unlikely Contender Rises in France as the A...     0
#
# [63122 rows x 2 columns]

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                                            combined_text label
# 0      As U.S. budget fight looms, Republicans flip t...     0
# 1      U.S. military to accept transgender recruits o...     0
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...     0
# 3      FBI Russia probe helped by Australian diplomat...     0
# 4      Trump wants Postal Service to charge 'much mor...     0
# ...                                                  ...   ...
# 72108  Kris Kobach: Democrats Already Attacking Elect...     0
# 72109  Police Are Now Warning People To Take A Photo ...     1
# 72117  Tested by Russia, NATO Struggles to Stay Credi...     0
# 72123  Dallas, Roger Federer, Hillary Clinton: Your F...     0
# 72124  An Unlikely Contender Rises in France as the A...     0
#
# [63122 rows x 2 columns]

# %%
df.to_csv("FinalDataset.csv")
